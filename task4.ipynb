# %% [markdown]
# # <a id="#">Task 4 – Edge detection: Derivative operators</a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Prewitt filters
#
# **<a id="#">Task 4.1.1.</a>** Load the image `data/astronaut.png` and show it:

# %%
img=plt.imread('data/astronaut.png')
plt.imshow(img, 'grey')

# %% [markdown]
# **<a id="#">Task 4.1.2.</a>** Implement horizontal and vertical 3&times;3 Prewitt filters:

# %%
def prewitt_h(img_in):
    result = numpy.zeros(img_in.shape)
    for p in numpy.ndindex(img_in.shape):
        neighborhood_sum =[]
        if p[0] > 0 and p[1] > 0 and p[0] < img_in.shape[0]-1 and p[1] < img_in.shape [1]-1:
            for q in np.ndindex(3,3):
                if q[1] == 0:
                    neighborhood_sum.append(img_in[p[0]+q[0]-1, p[1]+q[1]-1]*1)
                if q[1] ==2:
                    neighborhood_sum.append(img_in[p[0]+q[0]-1, p[1]+q[1]-1]*(-1))
            result[p] = sum(neighborhood_sum)/6
        else:
            result[p] = 0
    return result
def prewitt_v(img_in):
    result = numpy.zeros(img_in.shape)
    for p in numpy.ndindex(img_in.shape):
        neighborhood_sum =[]
        if p[0] > 0 and p[1] > 0 and p[0] < img_in.shape[0]-1 and p[1] < img_in.shape [1]-1:
            for q in np.ndindex(3,3):
                if q[0] == 0:
                    neighborhood_sum.append(img_in[p[0]+q[0]-1, p[1]+q[1]-1]*1)
                if q[0] ==2:
                    neighborhood_sum.append(img_in[p[0]+q[0]-1, p[1]+q[1]-1]*(-1))
            result[p] = sum(neighborhood_sum)/6
        else:
            result[p] = 0
    return result

# %% [markdown]
# **<a id="#">Task 4.1.3.</a>** Test your above solution using the functions `prewitt_h` and `prewitt_v` for the previously loaded image and show the result:

# %%
prewitt_h(img)
plt.imshow(prewitt_h(img))
plt.colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable: 'ScalarMappable | None' = None, cax: 'matplotlib.axes.Axes | None' = None, ax: 'matplotlib.axes.Axes | Iterable[matplotlib.axes.Axes] | None' = None, **kwargs) -> 'Colorbar'>

# %%
prewitt_v(img)
plt.imshow(prewitt_v(img))
plt.colorbar()

# %% [markdown]
# **<a id="#">Task 4.1.4.</a>** Compare your results with the correct result image `data/astronaut_prewitt_h.tiff` and `data/astronaut_prewitt_v.tiff`:

# %%
import skimage.io
img_L_H=skimage.io.imread('data/astronaut_prewitt_h.tiff')
img_L_V=skimage.io.imread('data/astronaut_prewitt_v.tiff')
assert numpy.allclose(prewitt_v(img), img_L_H, atol=1/255)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[79], line 4
#       2 img_L_H=skimage.io.imread('data/astronaut_prewitt_h.tiff')
#       3 img_L_V=skimage.io.imread('data/astronaut_prewitt_v.tiff')
# ----> 4 assert numpy.allclose(prewitt_v(img), img_L_H, atol=1/255)
#
# AssertionError:

# %%
import skimage.io
img_L_H=skimage.io.imread('data/astronaut_prewitt_h.tiff')
skimage.io.imshow(img_L_H)

# %% [markdown]
# ---
#
# ## Edge detection
#
# **<a id="#">Task 4.2.1.</a>** Use your results from **Task 4.1.2 – 4.1.3** to compute the *gradient magnitude* of the image:

# %%
Magnitute=numpy.sqrt(prewitt_h(img)**2+prewitt_v(img)**2)
plt.imshow(Magnitute)
plt.colorbar()

# %% [markdown]
# **<a id="#">Task 4.2.2.</a>** Compare your result with the correct result image `data/astronaut_prewitt_gradmag.tiff`:

# %%
import skimage.io
img_L_G=skimage.io.imread('data/astronaut_prewitt_gradmag.tiff')
assert numpy.allclose(Magnitute, img_L_G, atol=1/255)

# %% [markdown]
# ---
#
# ## Sobel filters (bonus)
#
# **<a id="#">Task 4.3.1.</a>** Implement the two functions `sobel_h` and `sobel_v` for horizontal and vertical 3&times;3 Sobel filtering, respectively:

# %% [markdown]
# **<a id="#">Task 4.3.2.</a>** Test your above solution using the functions `sobel_h` and `sobel_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.3.3.</a>** Compare your results with the correct result image `data/astronaut_sobel_h.tiff` and `data/astronaut_sobel_v.tiff`:
